# %% [markdown]
# **list**

# %%
l1=[1,2,3,4,5]
l2=['A','B','C','D']
l3=[10,20,30,40,'A','B','C','D']
l4=[10,10,10,10]
l5=[10,['A','B','C']]
l6=[1,1.5,'apple',True,['A'],(10,20)]
l7=[]

# %%
l6
# Out:
# [1, 1.5, 'apple', True, ['A'], (10, 20)]

# %% [markdown]
# - only comparison function fail when we have different data types
#
#     - sum
#
#     - min
#
#     - max
#
#     - sorted
#
# - len
#
# - reversed works when when we have different data types

# %%
l1=[10,20,30,40]

# %%
for i in l1:
    print(i,end=" ")
# Out:
# 10 20 30 40

# %%
for i in range(len(l1)):
    print(l1[i])
# Out:
# 10
# 20
# 30
# 40

# %%
l1=[10,20]
l1[1]
# Out:
# 20

# %%
l1=[10,[20,30]]
# how many elements are there l1:2
# 10,[20,30]
len(l1)
# what are the possible 0 and 1
l1[1]
# how the output is a list
# element are 2
l1[1][0]
# Out:
# 20

# %%
l1=[[10]]
l1[0][0]
# Out:
# 10

# %%
l1=[10,[20,30,[40]]]
l1[1][2][0]
# Out:
# 40

# %%
l1=['Orange',['Nagpur',['MH',['Shivaji',['shamabji',['Chava',['Vikcy']]]]]]]
l1[1][1][1][1][1][1]
# Out:
# ['Vikcy']

# %%
l1=[[[[[[[['onion']]]]]]]]
l1[0][0][0][0][0][0][0][0]
# Out:
# 'onion'

# %%
dir([])
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
l1=[10,20,30]
l1.clear()

# %%
l1
# Out:
# []

# %%
l1=[10,20,30]
l1.copy()
# Out:
# [10, 20, 30]

# %%
l1=[10,20,30]
l1.count(10)
l1
# Out:
# [10, 20, 30]

# %%
l1=[10,20,30]
l1.index

# %%
l1=[10,20,30]
l1.reverse()

# %%
l1
# Out:
# [30, 20, 10]

# %%
l1=[10,20,30]
l1.append('apple')

# %%
l1
# Out:
# [10, 20, 30, 'apple']

# %%
l1.extend([8,9,10])

# %%
l=[]
l.append(20)
l.append('apple')
l.append([10,20])
l
# Out:
# [20, 'apple', [10, 20]]

# %%
l2=[]
l2.append(0)
l2.append(1)
l2.append(2)

# %%
for i in range(4):
    l2.append(i)

l2
# Out:
# [0, 1, 2, 0, 1, 2, 3]

# %%
import random
l=[]
for i in range(10):
    num=random.randint(1,100)
    if num%2==0:
        l.append(i)

l
# Out:
# [1, 3, 4, 6]

# %%
import random
even=[]
odd=[]
for i in range(5):
    num=random.randint(1,100)
    if num%2==0:
        # print(num)
        even.append(num)
    else:
        odd.append(num)

even
# Out:
# [6, 70, 58]

# %%
l=['hyd','mumbai','pune','chennai']
out=[]
for i in l:
    out.append(i.upper())

out
# Out:
# ['HYD', 'MUMBAI', 'PUNE', 'CHENNAI']

# %%
l=['hyd','mum#bai','pune','chen#nai']
out=[]
for i in l:
    if '#' in i:
        out.append(i)
 
out
# Out:
# ['mum#bai', 'chen#nai']

# %%
l=['hyd','mumbai','pune','chennai']
out=[]
for i in l:
    if len(i)>4:
         out.append(i)
  

out
# Out:
# ['mumbai', 'chennai']

# %%
l1=[10,20,30,40]
l2=['Apple','Banana','Cherry']
l2.extend(l1)
l2
# Out:
# ['Apple', 'Banana', 'Cherry', 10, 20, 30, 40]

# %%
l1=[10,20,30,40]
l1.i

# %%
l1=[10,20,30,'Apple','Banana','Chery']
l1.pop()   # Remove and return item at index
l1
# Out:
# [10, 20, 30, 'Apple', 'Banana']

# %%
i1=l1.index('Banana')
i1
l1.pop(i1)
# Out:
# 'Banana'

# %%
l1=[10,20,30,'Apple','Banana','Chery','Apple']
l1.remove('Apple')
l1
# Out:
# [10, 20, 30, 'Banana', 'Chery', 'Apple']

# %%
str1='hi how are you'
str1.split()
# Out:
# ['hi', 'are', 'you']

# %%
str1='hi how, are you'
str1.split()
# Out:
# ['hi', 'how,', 'are', 'you']

# %%
str1='hi how, are you'
str1.split('o')
# Out:
# ['hi h', 'w, are y', 'u']

# %%
str1='hi how, are you'
str1.split(',')
# Out:
# ['hi how', ' are you']

# %%
str1='hi how, are you'
str1.split(' ')
# Out:
# ['hi', 'how,', 'are', 'you']

# %%
str1='hi how, are you'
s=''
s.join(str1)
# Out:
# 'hi how, are you'

# %%
str1='hi how', 'are you'
s='--->'
s.join(str1)
# Out:
# 'hi how--->are you'

# %%
str1='hi how, are you'
s=

# %%
l=['a','b','c']
s='***'
s.join(l)
# Out:
# 'a***b***c'
