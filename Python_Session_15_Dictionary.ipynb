# %%
Names=['Ramesh','Mahesh','Suresh']
Age=[20,22,24]
for i in range(len(Names)):
    print(f"{Names[i]} has age is {Age[i]}")
# Out:
# Ramesh has age is 20
# Mahesh has age is 22
# Suresh has age is 24

# %% [markdown]
# **zip**

# %%
Names=['Ramesh','Mahesh','Suresh']
Age=[20,22,24]
zip(Names,Age)

# %%
list(zip(Names,Age))
# Out:
# [('Ramesh', 20), ('Mahesh', 22), ('Suresh', 24)]

# %%
for i in zip(Names,Age):
    print(i)
# Out:
# ('Ramesh', 20)
# ('Mahesh', 22)
# ('Suresh', 24)

# %%
for i,j in zip(Names,Age):
    print(f"{i} has age is {j}")
    # print(i,j)
# Out:
# Ramesh has age is 20
# Mahesh has age is 22
# Suresh has age is 24

# %%
- key:value

# %%
d1={'Ramesh':20,'Mahesh':22,'Suresh':24}
d1
# Out:
# {'Ramesh': 20, 'Mahesh': 22, 'Suresh': 24}

# %%
keys= 'Ramesh','Mahesh','Suresh'
values= 20,22,24

# %%
d1={'Ramesh':20,'Mahesh':22,'Suresh':24}

# %%
for i,j in zip(d1):
    print(f'{j} has age is {j}')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 for i,j in zip(d1):
#       2     print(f'{j} has age is {j}')
#
# ValueError: not enough values to unpack (expected 2, got 1)

# %%
d1={'Ramesh': 20, 'Mahesh': 22, 'Suresh':24}

d2={20:'Ramesh', 22: 'Mahesh', 24: 'Suresh'}

d3={'Name': 'Ramesh'}

d5={'Ramesh': 20, 'Mahesh': 20, 'Suresh':20}

d6={'Ramesh':20, 'Ramesh': 22, 'Suresh':20}

d7={'Names': ['Ramesh', 'Mahesh', 'Suresh']}

d8={'Names': ('Ramesh', 'Mahesh', 'Suresh')}

d9={['Ramesh', 'Mahesh', 'Suresh']: 'Names'}

d10={('Ramesh', 'Mahesh', 'Suresh'): 'Names'}

d11={{'Name': 'Ramesh'}}
# Out:
# {('Ramesh', 'Mahesh', 'Suresh'): 'Names'}

# %% [markdown]
# **keys are important**

# %%
d1={'Ramesh':20,'Mahesh':22,'Suresh':24}
min(d1)
# Out:
# 'Mahesh'

# %%
d1={'Ramesh':20,'Mahesh':22,'Suresh':24}
max(d1)
# Out:
# 'Suresh'

# %%
d1={'Ramesh':20,'Mahesh':22,'Suresh':18}
for i in d1:
    print(i)
# Out:
# Ramesh
# Mahesh
# Suresh

# %%
d1[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 d1[0]
#
# KeyError: 0

# %%
d1['Ramesh']
# Out:
# 20

# %%
for i in d1:
    print(i,d1[i])
# Out:
# Ramesh 20
# Mahesh 22
# Suresh 18

# %%
d1={'Apple':[100]}
d1['Apple'][0]
# Out:
# 100

# %%
d2={'Fruites':[{'Apple':100}]}

# %%
d2['Fruites'][0]['Apple']
# Out:
# 100

# %%
d3={'Fruites':{'Apple':{'Kashmir':{'India'}}}}

# %%
d3['Fruites']['Apple']['Kashmir']
# Out:
# {'India'}

# %%
d4={'Fruites':[{'Orange':[{'MH':[{'Shivaji':[{'Shambaji':[{'Chava':['Vicky']}]}]}]}]}]}

# %%
['Fruites'][0]
# Out:
# 'Fruites'

# %%
['Orange'][0]
# Out:
# 'Orange'

# %%
['MH'][0]
# Out:
# 'MH'

# %%
['Shambaji'][0]
# Out:
# 'Shambaji'

# %%
['Chava'][0]
# Out:
# 'Chava'

# %%
['Vicky']
# Out:
# 'Vicky'

# %%
d4['Fruites'][0]['Orange'][0]['MH'][0]['Shivaji'][0]['Shambaji'][0]['Chava']
# Out:
# ['Vicky']

# %%
dir(set)
# Out:
# ['__and__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iand__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__isub__',
#  '__iter__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__rand__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__ror__',
#  '__rsub__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__xor__',
#  'add',
#  'clear',
#  'copy',
#  'difference',
#  'difference_update',
#  'discard',
#  'intersection',
#  'intersection_update',
#  'isdisjoint',
#  'issubset',
#  'issuperset',
#  'pop',
#  'remove',
#  'symmetric_difference',
#  'symmetric_difference_update',
#  'union',
#  'update']

# %%
l1=['Apple','Orang#e'
l1.

# %%
# string
s=''
s=s+'A'
s
# Out:
# 'A'

# %%
l=[]
l.append('Apple')
l
# Out:
# ['Apple']

# %%
d={'Ramesh':20,'Mahesh':22,'Suresh':24}

# %%
d={}
d['Ramesh']=20
d
# Out:
# {'Ramesh': 20}

# %%
d1={'Name':'Suresh'}
d1['Name']='Mahesh'
d1
# Out:
# {'Name': 'Mahesh'}

# %%
Names=['Ramesh','Mahesh','Suresh']
Age=[20,22,24]

d={}
d['Ramesh']=20
d['Mahesh']=22
d['Suresh']=24

# %%
d={}
for i,j in zip(Names,Age):
    d[i]=j
d
# Out:
# {'Ramesh': 20, 'Mahesh': 22, 'Suresh': 24}

# %%
d={i:j for i,j in zip(Names,Age)}
d
# Out:
# {'Ramesh': 20, 'Mahesh': 22, 'Suresh': 24}

# %%
d={'Ramesh':20,'Mahesh':22,'Suresh':24}
l1=[i for i in d]
l2=[d[i] for i in d]
# for i in d:
#     l1.append(i)
#     l2.append(j)
l1,l2
# Out:
# (['Ramesh', 'Mahesh', 'Suresh'], [20, 22, 24])

# %%
d={'Ramesh':20,'Mahesh':22,'Suresh':24}
d.keys().count('Suresh')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[33], line 2
#       1 d={'Ramesh':20,'Mahesh':22,'Suresh':24}
# ----> 2 d.keys().count('Suresh')
#
# AttributeError: 'dict_keys' object has no attribute 'count'

# %%
d={'Ramesh':20,'Mahesh':22,'Suresh':24}
list(d.keys())
# Out:
# ['Ramesh', 'Mahesh', 'Suresh']

# %%
str1='python is a easy and python is powerful'
l=str1.split()
l1=[]
d={}
for i in l:
    a=l.count(i)
    l1.append(a)
for i,j in zip(l,l1):
    d[i]=j
d
# Out:
# {'python': 2, 'is': 2, 'a': 1, 'easy': 1, 'and': 1, 'powerful': 1}

# %%
d2={'Ramesh':85,'Mahesh':90,'Suresh':75}
max(d2)
# Out:
# 'Suresh'

# %%
list=['apple','ate','ball','bat','cat','cow']    
a=[]
b=[]
c=[]
for i in list:
    if i[0]=='a':
        a.append(i)
for i in list:
    if i[0]=='b':
        b.append(i)
for i in list:
    if i[0]=='c':
        c.append(i)
a,b,c
# Out:
# (['apple', 'ate'], ['ball', 'bat'], ['cat', 'cow'])

# %%
d1={'a':1,'b':2,'c':3}
d1.
# Out:
# <function dict.keys()>

# %%
d3={'a':1,'b':20,'c':30}

# %%
list=['Apple','ate','ball','bat','cat','cow']    
a=[]
# b=[]
# c=[]
for i in list:
    if i[0]=='a':
        a.append(i)
a
# Out:
# ['ate']
